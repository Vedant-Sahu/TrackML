# %%
import pandas as pd
import tensorflow as tf
import numpy as np
from trackml.dataset import *

#plotting 
import matplotlib.pyplot as plt 
from mpl_toolkits import mplot3d
# %matplotlib notebook

# %%
df = pd.read_csv('train_100_events/event000001099-particles.csv')
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(df.vx,df.vy,df.vz, 'o', markersize=1.)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">

# %%
event_prefix = 'event000001000'
hits, cells, particles, truth = load_event(os.path.join('train_100_events', event_prefix))

mem_bytes = (hits.memory_usage(index=True).sum() 
             + cells.memory_usage(index=True).sum() 
             + particles.memory_usage(index=True).sum() 
             + truth.memory_usage(index=True).sum())
print('{} memory usage {:.2f} MB'.format(event_prefix, mem_bytes / 2**20))
# Out:
# event000001000 memory usage 18.46 MB

# %%
truth = pandas.DataFrame(truth)
hits = pd.DataFrame(hits)
cells = pd.DataFrame(cells)
particles = pd.DataFrame(particles)

# %%
truth.sort_values(by=['particle_id'])
one_particle = truth.loc[truth['particle_id'] == 968305530843955200]
print(one_particle)
# Out:
#        hit_id         particle_id          tx          ty           tz  \
# 16330   16331  968305530843955200  -57.447498  164.901993  -602.000000
# 18963   18964  968305530843955200   -6.203050   31.136801  -108.509003
# 26955   26956  968305530843955200  -16.709900   70.571701  -248.927994
# 33744   33745  968305530843955200  -31.689301  111.808998  -399.891998
# 70919   70920  968305530843955200 -171.311005  302.390015 -1218.500000
# 71481   71482  968305530843955200 -106.626999  236.916000  -900.963013
#
#             tpx       tpy       tpz    weight
# 16330 -0.143015  0.254727 -0.997839  0.000007
# 18963 -0.063428  0.284947 -1.000540  0.000024
# 26955 -0.087418  0.277445 -1.000210  0.000016
# 33744 -0.111333  0.268470 -0.999714  0.000011
# 70919 -0.219460  0.185294 -0.996958  0.000014
# 71481 -0.184913  0.224070 -0.996904  0.000009

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(one_particle.tx,one_particle.ty,one_particle.tz, 'o', markersize=1.)
plt.title('Hits for particle #' + str(968305530843955200))
plt.xlabel('x')
plt.ylabel('y')
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
# Text(0.5,0,'y')

# %%
#3D linear regression
