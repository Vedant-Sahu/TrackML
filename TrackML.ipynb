# %%
import pandas as pd
import tensorflow as tf
import numpy as np

#plotting 
import matplotlib.pyplot as plt 
from mpl_toolkits import mplot3d
# %matplotlib notebook

# %%
df = pd.read_csv('train_100_events/event000001099-particles.csv')
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(df.vx,df.vy,df.vz, 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot_wireframe(df.vx, df.vy, df.vz, rstride=5, cstride=5)
# rotate the axes and update
for angle in range(0, 360):
    ax.view_init(30, angle)
    plt.draw()
    plt.pause(.001)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-eceb45c82564> in <module>()
# ----> 1 ax.plot_wireframe(df.vx, df.vy, df.vz, rstride=5, cstride=5)
#       2 # rotate the axes and update
#       3 for angle in range(0, 360):
#       4     ax.view_init(30, angle)
#       5     plt.draw()
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/mpl_toolkits/mplot3d/axes3d.py in plot_wireframe(self, X, Y, Z, *args, **kwargs)
#    1833         had_data = self.has_data()
#    1834         if Z.ndim != 2:
# -> 1835             raise ValueError("Argument Z must be 2-dimensional.")
#    1836         # FIXME: Support masked arrays
#    1837         X, Y, Z = np.broadcast_arrays(X, Y, Z)
#
# ValueError: Argument Z must be 2-dimensional.
